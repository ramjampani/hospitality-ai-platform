# %%
# revenue_forecasting.py

import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import os

# %%
# --- Load Data ---
def load_data():
    df = pd.read_csv("data/revenue_summary.csv", parse_dates=["date"])
    df['total_revenue'] = df['room_revenue'] + df['fnb_revenue']
    return df[['date', 'total_revenue']].rename(columns={"date": "ds", "total_revenue": "y"})

# %%
df=load_data()
df.head()
# Out:
#           ds         y
# 0 2022-01-01  18133.78
# 1 2022-01-02  26261.93
# 2 2022-01-03  23025.48
# 3 2022-01-04  16312.34
# 4 2022-01-05  18400.99

# %%
# --- Train Model ---
def train_model(df):
    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=True,
        daily_seasonality=False
    )
    model.fit(df)
    return model

# %%
model=train_model(df)
# Out:
# 22:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 22:34:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
# --- Forecast Future ---
def forecast_revenue(model, periods=90):
    future = model.make_future_dataframe(periods=periods)
    forecast = model.predict(future)
    return forecast

# %%
forecast=forecast_revenue(model)
forecast.head()
# Out:
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2022-01-01  21351.828844  16078.828997  26172.890407  21351.828844
# 1 2022-01-02  21351.262216  16868.060883  25690.475166  21351.262216
# 2 2022-01-03  21350.695588  17375.349842  26228.576508  21350.695588
# 3 2022-01-04  21350.128960  16704.907409  25887.725535  21350.128960
# 4 2022-01-05  21349.562333  16943.766326  25924.562026  21349.562333
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  21351.828844      -55.740841            -55.740841            -55.740841
# 1  21351.262216      203.439176            203.439176            203.439176
# 2  21350.695588      378.644293            378.644293            378.644293
# 3  21350.128960      132.192004            132.192004            132.192004
# 4  21349.562333       54.093148             54.093148             54.093148
#
#        weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 0   -3.649296     -3.649296     -3.649296  -52.091545    -52.091545
# 1  174.539941    174.539941    174.539941   28.899235     28.899235
# 2  261.693300    261.693300    261.693300  116.950993    116.950993
# 3  -77.524550    -77.524550    -77.524550  209.716553    209.716553
# 4 -250.562937   -250.562937   -250.562937  304.656085    304.656085
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0    -52.091545                   0.0                         0.0
# 1     28.899235                   0.0                         0.0
# 2    116.950993                   0.0                         0.0
# 3    209.716553                   0.0                         0.0
# 4    304.656085                   0.0                         0.0
#
#    multiplicative_terms_upper          yhat
# 0                         0.0  21296.088003
# 1                         0.0  21554.701392
# 2                         0.0  21729.339881
# 3                         0.0  21482.320964
# 4                         0.0  21403.655481

# %%
# --- Plot Results ---
def plot_forecast(df, forecast):
    model.plot(forecast)
    plt.title("Revenue Forecast")
    plt.xlabel("Date")
    plt.ylabel("Total Revenue")
    plt.tight_layout()
    plt.savefig("outputs/revenue_forecast_plot.png")
    plt.show()

# %%
results=plot_forecast(df,forecast)

# %%
# --- Save Forecast to CSV ---
def save_forecast(forecast):
    forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].to_csv("outputs/revenue_forecast.csv", index=False)

# %%
# --- Run Pipeline ---
def main():
    os.makedirs("outputs", exist_ok=True)
    df = load_data()
    model = train_model(df)
    forecast = forecast_revenue(model)
    plot_forecast(df, forecast)
    save_forecast(forecast)
    print("✅ Forecast complete. Outputs saved to 'outputs/' folder.")

# %%
if __name__ == "__main__":
    main()
# Out:
# 22:34:09 - cmdstanpy - INFO - Chain [1] start processing
# 22:34:09 - cmdstanpy - INFO - Chain [1] done processing
# ✅ Forecast complete. Outputs saved to 'outputs/' folder.
